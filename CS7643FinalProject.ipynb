# %%
# Mount into drive
import time
import copy
import pathlib
import os

from google.colab import drive

drive.mount("/content/drive")

# %cd '/content/drive/MyDrive/CS7643/FinalProject/'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/18DzphWfHEkGdHaXfkSrWGl0v37qf7tZ-/FinalProject

# %%
import torch
DEVICE= torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("USING device :",DEVICE)
# Out:
# USING device : cuda

# %%
# relevant imports
import pandas as pd
import numpy as np
import torch
from PIL import Image
import io
import pathlib
import time
import copy
import matplotlib.pyplot as plt
import torchvision
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torchvision import models
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
from torch.nn import Parameter

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def check_accuracy(output, target):
    """Computes the precision@k for the specified values of k"""
    batch_size = target.shape[0]

    _, pred = torch.max(output, dim=-1)

    correct = pred.eq(target).sum().item() #* 1.0

    acc = correct / batch_size

    return acc, pred

class Trainer(object):
    def __init__(self, model, optimizer,criterion, config):
        self.model = model
        self.optimizer = optimizer
        self.criterion = criterion
        self.config = config
        self.save_best = True
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.scheduler = None
        if config['scheduler']['set_scheduler']:
            self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
                        self.optimizer,
                        mode='min',
                        factor=config['scheduler']['factor'],
                        patience=config['scheduler']['patience'],
                        verbose=True,
                        min_lr=config['scheduler']['min_lr']
                    )

        print("USING device :", self.device)
        self.model = self.model.to(self.device)
        self.criterion = self.criterion.to(self.device)
        save_dir = f"checkpoints/{self.config['model_name']}"
        basedir = pathlib.Path().parent.resolve()
        checkpoint_path = pathlib.Path(basedir/save_dir)
        self.checkpoint_path = checkpoint_path

    def train_step(self, epoch):
        iter_time = AverageMeter()
        losses = AverageMeter()
        acc = AverageMeter()

        self.model.train()

        for idx, (data, target) in enumerate(train_loader):
            start = time.time()

            data = data.to(self.device)
            target = target.to(self.device)

            self.optimizer.zero_grad()
            out = self.model(data)
            batch_acc, pred = check_accuracy(out, target.squeeze(1))
            loss = criterion(out, target.squeeze(1).long())
            loss.backward()
            self.optimizer.step()

            losses.update(loss.item(), out.shape[0])
            acc.update(batch_acc, out.shape[0])

            iter_time.update(time.time() - start)
            if idx % 10 == 0:
                print(
                    (
                        "Epoch: [{0}][{1}/{2}]\t"
                        "Time {iter_time.val:.3f} ({iter_time.avg:.3f})\t"
                        "Loss {loss.val:.4f} ({loss.avg:.4f})\t"
                        "Prec @1 {top1.val:.4f} ({top1.avg:.4f})\t"
                    ).format(
                        epoch,
                        idx,
                        len(train_loader),
                        iter_time=iter_time,
                        loss=losses,
                        top1=acc,
                    )
                )
        return acc.avg, losses.avg

    def evaluate_step(self, epoch):
        iter_time = AverageMeter()
        losses = AverageMeter()
        acc = AverageMeter()

        num_class = self.config['num_classes']
        cm = torch.zeros(num_class, num_class)
        self.model.eval()

        # evaluation loop

        for idx, (data, target) in enumerate(val_loader):
            start = time.time()

            data = data.to(self.device)
            target = target.to(self.device)
            with torch.no_grad():
                out = self.model(data)
                batch_acc, pred = check_accuracy(out, target.squeeze(1).long())
                loss = criterion(out, target.squeeze(1).long())

            # update confusion matrix
            _, preds = torch.max(out, 1)
            for t, p in zip(target.view(-1), preds.view(-1)):
                cm[t.long(), p.long()] += 1

            losses.update(loss.item(), out.shape[0])
            acc.update(batch_acc, out.shape[0])

            iter_time.update(time.time() - start)
            if idx % 10 == 0:
                print(
                    (
                        "Epoch: [{0}][{1}/{2}]\t"
                        "Time {iter_time.val:.3f} ({iter_time.avg:.3f})\t"
                    ).format(
                        epoch,
                        idx,
                        len(val_loader),
                        iter_time=iter_time,
                        loss=losses,
                        top1=acc,
                    )
                )
        cm = cm / cm.sum(1)
        per_cls_acc = cm.diag().detach().numpy().tolist()
        for i, acc_i in enumerate(per_cls_acc):
            print("Accuracy of Class {}: {:.4f}".format(i, acc_i))

        print("* Prec @1: {top1.avg:.4f}".format(top1=acc))
        return cm, acc.avg, losses.avg

    def test_step(self):
        iter_time = AverageMeter()
        losses = AverageMeter()
        acc = AverageMeter()

        num_class = self.config['num_classes']
        cm = torch.zeros(num_class, num_class)
        self.model.eval()

        # evaluation loop

        for idx, (data, target) in enumerate(test_loader):
            start = time.time()

            data = data.to(self.device)
            target = target.to(self.device)
            with torch.no_grad():
                out = self.model(data)
                batch_acc, pred = check_accuracy(out, target.squeeze(1).long())
                loss = criterion(out, target.squeeze(1).long())

            # update confusion matrix
            _, preds = torch.max(out, 1)
            for t, p in zip(target.view(-1), preds.view(-1)):
                cm[t.long(), p.long()] += 1

            losses.update(loss.item(), out.shape[0])
            acc.update(batch_acc, out.shape[0])

            iter_time.update(time.time() - start)
            if idx % 10 == 0:
                print(
                    (
                      "Time {iter_time.val:.3f} ({iter_time.avg:.3f})\t"
                    ).format(
                        iter_time=iter_time,
                        loss=losses,
                        top1=acc,
                    )
                )
        cm = cm / cm.sum(1)
        per_cls_acc = cm.diag().detach().numpy().tolist()
        for i, acc_i in enumerate(per_cls_acc):
            print("Accuracy of Class {}: {:.4f}".format(i, acc_i))

        print("* Prec @1: {top1.avg:.4f}".format(top1=acc))
        return cm, acc, losses


    def train(self):
        best = 0
        best_cm = None
        best_model = None
        train_losses = []
        train_accs = []
        val_losses = []
        val_accs = []
        for epoch in range(self.config['epochs']):

            # train loop
            train_acc, train_loss = self.train_step(epoch)

            # validation loop
            cm,acc,loss = self.evaluate_step(epoch)

            current_lr = self.optimizer.param_groups[0]['lr']
            print('current_learning_rate', current_lr)
            if self.scheduler:
                self.scheduler.step(loss)

            if acc > best:
                best = acc
                best_cm = cm
                best_model = copy.deepcopy(model)
            train_losses.append(train_loss)
            train_accs.append(train_acc)
            val_losses.append(loss)
            val_accs.append(acc)
        print("Best Prec @1 Acccuracy: {:.4f}".format(best))
        per_cls_acc = best_cm.diag().detach().numpy().tolist()
        for i, acc_i in enumerate(per_cls_acc):
            print("Accuracy of Class {}: {:.4f}".format(i, acc_i))

        if self.save_best:
            if not pathlib.Path(self.checkpoint_path).exists():
                pathlib.Path(self.checkpoint_path).mkdir(parents=True, exist_ok=True)
                print(f"Directory {self.heckpoint_path} created successfully")
            else:
                print(f"Directory {self.checkpoint_path} already exists")

            torch.save(
                best_model.state_dict(),
                str(self.checkpoint_path) + "/model_checkpoint.pth",
            )

        epochs = range(len(train_losses))
        plt.plot(epochs, train_losses, label='train')
        plt.plot(epochs, val_losses, label='valid')

        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.title('Loss Curve')
        plt.savefig(str(self.checkpoint_path)+'/loss_curve.png')
        plt.show()
        plt.plot(epochs, train_accs, label='train')
        plt.plot(epochs, val_accs, label='valid')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.title('Accuracy Curve')
        plt.savefig(str(self.checkpoint_path)+'/accuracy_curve.png')
        plt.show()

# %%
def _weights_init(m):
    classname = m.__class__.__name__
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight)

class NormedLinear(nn.Module):

    def __init__(self, in_features, out_features):
        super(NormedLinear, self).__init__()
        self.weight = Parameter(torch.Tensor(in_features, out_features))
        self.weight.data.uniform_(-1, 1).renorm_(2, 1, 1e-5).mul_(1e5)

    def forward(self, x):
        out = F.normalize(x, dim=1).mm(F.normalize(self.weight, dim=0))
        return out

class LambdaLayer(nn.Module):

    def __init__(self, lambd):
        super(LambdaLayer, self).__init__()
        self.lambd = lambd

    def forward(self, x):
        return self.lambd(x)


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1, option='A'):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            if option == 'A':
                """
                For CIFAR10 ResNet paper uses option A.
                """
                self.shortcut = LambdaLayer(lambda x:
                                            F.pad(x[:, :, ::2, ::2], (0, 0, 0, 0, planes//4, planes//4), "constant", 0))
            elif option == 'B':
                self.shortcut = nn.Sequential(
                     nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                     nn.BatchNorm2d(self.expansion * planes)
                )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet_s(nn.Module):

    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet_s, self).__init__()
        self.in_planes = 16

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        self.layer1 = self._make_layer(block, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64, num_blocks[2], stride=2)

        self.linear = nn.Linear(64, num_classes)
        self.apply(_weights_init)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion

        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def resnet32(num_classes=10, use_norm=False):
    return ResNet_s(BasicBlock, [5, 5, 5], num_classes=num_classes)

# %%
import yaml
with open('config.yaml', 'r') as file:
    cfg = yaml.safe_load(file)
print(cfg)
# Out:
# {'model_name': 'resnet152', 'batch_size': 256, 'epochs': 15, 'lr': 0.0001, 'scheduler': {'set_scheduler': True, 'patience': 5, 'factor': 0.5, 'min_lr': 1e-06}, 'num_classes': 20, 'size': 224, 'n_classes': 20, 'weight_decay': 0.0001}

# %%
# gets the data and creates the train/test splits
import data_loader

dl = data_loader.DataLoader(size=cfg['size'], use_fraction=1)
dl.main()
# get the  train and test images/labels
train_images, train_labels = dl.return_train_data()
test_images, test_labels = dl.return_test_data()
label_names = dl.labelNames

del dl
print(label_names)
train_dataset = TensorDataset(train_images, train_labels)
test_dataset = TensorDataset(test_images, test_labels)
train_images.shape, test_images.shape
# Out:
# Downloading data...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# testing download
# torch.Size([3, 224, 224])
# tensor([[[-1.3815, -1.3815, -1.3815,  ..., -0.6794, -0.7137, -0.0287],
#          [-1.3815, -1.3815, -1.3815,  ..., -0.7479, -0.7993, -0.2684],
#          [-1.3815, -1.3815, -1.3815,  ..., -0.6965, -0.7993, -0.5767],
#          ...,
#          [-1.2445, -1.2274, -1.2103,  ..., -0.5938, -0.5767, -0.5253],
#          [-1.2445, -1.2274, -1.2103,  ..., -0.5767, -0.5596, -0.4911],
#          [-1.2445, -1.2274, -1.2103,  ..., -0.4397, -0.4054, -0.3198]],
#
#         [[-1.4580, -1.4580, -1.4580,  ..., -0.8102, -0.8452, -0.1450],
#          [-1.4580, -1.4580, -1.4580,  ..., -0.8803, -0.9328, -0.3901],
#          [-1.4580, -1.4580, -1.4580,  ..., -0.8452, -0.9503, -0.7052],
#          ...,
#          [-1.5105, -1.5105, -1.4930,  ..., -0.9153, -0.8803, -0.8102],
#          [-1.5105, -1.4930, -1.4755,  ..., -0.9153, -0.8803, -0.7927],
#          [-1.5105, -1.4930, -1.4755,  ..., -0.7752, -0.7227, -0.6352]],
#
#         [[-1.2641, -1.2641, -1.2641,  ..., -0.7936, -0.8458, -0.1487],
#          [-1.2641, -1.2641, -1.2641,  ..., -0.8110, -0.8981, -0.3578],
#          [-1.2641, -1.2641, -1.2641,  ..., -0.7238, -0.8458, -0.6193],
#          ...,
#          [-1.3339, -1.3164, -1.3164,  ..., -0.7761, -0.7587, -0.7761],
#          [-1.3339, -1.3164, -1.2990,  ..., -0.7761, -0.7587, -0.7587],
#          [-1.3339, -1.3164, -1.2990,  ..., -0.6367, -0.6018, -0.5844]]])
# converting data to tensors
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# n_indices selected 20000
# verifying processing
# {0: 'blues', 1: 'classical', 2: 'country', 3: 'deathmetal', 4: 'doommetal', 5: 'drumnbass', 6: 'electronic', 7: 'folk', 8: 'grime', 9: 'heavymetal', 10: 'hiphop', 11: 'jazz', 12: 'lofi', 13: 'pop', 14: 'psychedelicrock', 15: 'punk', 16: 'reggae', 17: 'rock', 18: 'soul', 19: 'techno'}
# (torch.Size([16000, 3, 224, 224]), torch.Size([4000, 3, 224, 224]))

# %%
from torchvision.models import resnet

if cfg['model_name'] =='resnet152':
    model = resnet.resnet152(weights=resnet.ResNet152_Weights.IMAGENET1K_V1)
    num_ftrs = model.fc.in_features
    # Here the size of each output sample is set to 2.
    # Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
    model.fc = nn.Linear(num_ftrs, cfg['num_classes'])
    for param in model.parameters():
        param.requires_grad = False
    model.fc.weight.requires_grad = True
    model.fc.bias.requires_grad = True
elif cfg['model_name'] =='resnet32':
    model = resnet32(num_classes=cfg['num_classes'])

# model = model.to(device)

from torchsummary import summary
import torch.optim as optim

criterion=nn.CrossEntropyLoss()

train_loader = DataLoader(train_dataset, batch_size=cfg['batch_size'], shuffle=True)

val_loader = DataLoader(test_dataset, batch_size=cfg['batch_size'], shuffle=False)
# Define the optimizer (Adam)
optimizer = optim.Adam(model.parameters(),lr=cfg['lr'], weight_decay=cfg['weight_decay'])
criterion = nn.CrossEntropyLoss()
trainer = Trainer(model, optimizer, criterion,config=cfg)
trainer.train()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /root/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
# 100%|██████████| 230M/230M [00:01<00:00, 209MB/s]
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# USING device : cuda
# Epoch: [0][0/63]	Time 1.716 (1.716)	Loss 3.0372 (3.0372)	Prec @1 0.0703 (0.0703)
# Epoch: [0][10/63]	Time 0.243 (0.377)	Loss 2.9750 (3.0083)	Prec @1 0.0742 (0.0589)
# Epoch: [0][20/63]	Time 0.243 (0.313)	Loss 2.9505 (2.9928)	Prec @1 0.0625 (0.0662)
# Epoch: [0][30/63]	Time 0.243 (0.291)	Loss 2.9211 (2.9770)	Prec @1 0.0977 (0.0731)
# Epoch: [0][40/63]	Time 0.243 (0.279)	Loss 2.9537 (2.9622)	Prec @1 0.0859 (0.0820)
# Epoch: [0][50/63]	Time 0.243 (0.272)	Loss 2.8855 (2.9507)	Prec @1 0.1367 (0.0902)
# Epoch: [0][60/63]	Time 0.242 (0.267)	Loss 2.8886 (2.9388)	Prec @1 0.0938 (0.0957)
# Epoch: [0][0/16]	Time 0.250 (0.250)
# Epoch: [0][10/16]	Time 0.238 (0.240)
# Accuracy of Class 0: 0.0353
# Accuracy of Class 1: 0.1685
# Accuracy of Class 2: 0.1244
# Accuracy of Class 3: 0.4493
# Accuracy of Class 4: 0.0701
# Accuracy of Class 5: 0.2210
# Accuracy of Class 6: 0.0895
# Accuracy of Class 7: 0.0574
# Accuracy of Class 8: 0.0529
# Accuracy of Class 9: 0.3005
# Accuracy of Class 10: 0.0309
# Accuracy of Class 11: 0.0808
# Accuracy of Class 12: 0.0321
# Accuracy of Class 13: 0.1990
# Accuracy of Class 14: 0.1185
# Accuracy of Class 15: 0.1594
# Accuracy of Class 16: 0.0950
# Accuracy of Class 17: 0.0441
# Accuracy of Class 18: 0.0622
# Accuracy of Class 19: 0.2267
# * Prec @1: 0.1315
# current_learning_rate 0.0001
# Epoch: [1][0/63]	Time 0.243 (0.243)	Loss 2.8638 (2.8638)	Prec @1 0.1250 (0.1250)
# Epoch: [1][10/63]	Time 0.243 (0.243)	Loss 2.8618 (2.8503)	Prec @1 0.1445 (0.1456)
# Epoch: [1][20/63]	Time 0.243 (0.243)	Loss 2.8049 (2.8376)	Prec @1 0.1562 (0.1520)
# Epoch: [1][30/63]	Time 0.243 (0.243)	Loss 2.7787 (2.8231)	Prec @1 0.1797 (0.1605)
# Epoch: [1][40/63]	Time 0.242 (0.243)	Loss 2.7898 (2.8176)	Prec @1 0.1719 (0.1602)
# Epoch: [1][50/63]	Time 0.243 (0.243)	Loss 2.7487 (2.8103)	Prec @1 0.1602 (0.1626)
# Epoch: [1][60/63]	Time 0.243 (0.243)	Loss 2.7454 (2.7997)	Prec @1 0.1836 (0.1672)
# Epoch: [1][0/16]	Time 0.240 (0.240)
# Epoch: [1][10/16]	Time 0.243 (0.239)
# Accuracy of Class 0: 0.0588
# Accuracy of Class 1: 0.4457
# Accuracy of Class 2: 0.1294
# Accuracy of Class 3: 0.5797
# Accuracy of Class 4: 0.1308
# Accuracy of Class 5: 0.1934
# Accuracy of Class 6: 0.0947
# Accuracy of Class 7: 0.1244
# Accuracy of Class 8: 0.3990
# Accuracy of Class 9: 0.2642
# Accuracy of Class 10: 0.0412
# Accuracy of Class 11: 0.0960
# Accuracy of Class 12: 0.0695
# Accuracy of Class 13: 0.1244
# Accuracy of Class 14: 0.0711
# Accuracy of Class 15: 0.1787
# Accuracy of Class 16: 0.0900
# Accuracy of Class 17: 0.0396
# Accuracy of Class 18: 0.1140
# Accuracy of Class 19: 0.1244
# * Prec @1: 0.1683
# current_learning_rate 0.0001
# Epoch: [2][0/63]	Time 0.243 (0.243)	Loss 2.7500 (2.7500)	Prec @1 0.1875 (0.1875)
# Epoch: [2][10/63]	Time 0.243 (0.243)	Loss 2.7488 (2.7361)	Prec @1 0.1680 (0.1875)
# Epoch: [2][20/63]	Time 0.243 (0.243)	Loss 2.7276 (2.7286)	Prec @1 0.1797 (0.1927)
# Epoch: [2][30/63]	Time 0.242 (0.243)	Loss 2.7075 (2.7259)	Prec @1 0.1914 (0.1953)
# Epoch: [2][40/63]	Time 0.243 (0.243)	Loss 2.6876 (2.7199)	Prec @1 0.2344 (0.1941)
# Epoch: [2][50/63]	Time 0.243 (0.243)	Loss 2.7195 (2.7117)	Prec @1 0.1992 (0.1984)
# Epoch: [2][60/63]	Time 0.244 (0.243)	Loss 2.7162 (2.7090)	Prec @1 0.1992 (0.1983)
# Epoch: [2][0/16]	Time 0.238 (0.238)
# Epoch: [2][10/16]	Time 0.240 (0.239)
# Accuracy of Class 0: 0.1471
# Accuracy of Class 1: 0.4239
# Accuracy of Class 2: 0.2338
# Accuracy of Class 3: 0.4300
# Accuracy of Class 4: 0.2243
# Accuracy of Class 5: 0.2928
# Accuracy of Class 6: 0.0684
# Accuracy of Class 7: 0.0574
# Accuracy of Class 8: 0.3846
# Accuracy of Class 9: 0.3627
# Accuracy of Class 10: 0.0876
# Accuracy of Class 11: 0.0909
# Accuracy of Class 12: 0.0535
# Accuracy of Class 13: 0.1592
# Accuracy of Class 14: 0.1422
# Accuracy of Class 15: 0.2850
# Accuracy of Class 16: 0.0700
# Accuracy of Class 17: 0.0000
# Accuracy of Class 18: 0.0984
# Accuracy of Class 19: 0.1867
# * Prec @1: 0.1890
# current_learning_rate 0.0001
# Epoch: [3][0/63]	Time 0.243 (0.243)	Loss 2.7133 (2.7133)	Prec @1 0.2109 (0.2109)
# Epoch: [3][10/63]	Time 0.243 (0.243)	Loss 2.6652 (2.6620)	Prec @1 0.2031 (0.2088)
# Epoch: [3][20/63]	Time 0.243 (0.243)	Loss 2.6269 (2.6611)	Prec @1 0.1680 (0.2091)
# Epoch: [3][30/63]	Time 0.243 (0.243)	Loss 2.6790 (2.6587)	Prec @1 0.2109 (0.2112)
# Epoch: [3][40/63]	Time 0.243 (0.243)	Loss 2.6197 (2.6580)	Prec @1 0.2031 (0.2090)
# Epoch: [3][50/63]	Time 0.243 (0.243)	Loss 2.6551 (2.6545)	Prec @1 0.1992 (0.2112)
# Epoch: [3][60/63]	Time 0.242 (0.243)	Loss 2.5605 (2.6470)	Prec @1 0.2773 (0.2145)
# Epoch: [3][0/16]	Time 0.238 (0.238)
# Epoch: [3][10/16]	Time 0.239 (0.239)
# Accuracy of Class 0: 0.0294
# Accuracy of Class 1: 0.5380
# Accuracy of Class 2: 0.3980
# Accuracy of Class 3: 0.5411
# Accuracy of Class 4: 0.1168
# Accuracy of Class 5: 0.2818
# Accuracy of Class 6: 0.0263
# Accuracy of Class 7: 0.0574
# Accuracy of Class 8: 0.3077
# Accuracy of Class 9: 0.4197
# Accuracy of Class 10: 0.1856
# Accuracy of Class 11: 0.0303
# Accuracy of Class 12: 0.1176
# Accuracy of Class 13: 0.1692
# Accuracy of Class 14: 0.1043
# Accuracy of Class 15: 0.2464
# Accuracy of Class 16: 0.0650
# Accuracy of Class 17: 0.0000
# Accuracy of Class 18: 0.0725
# Accuracy of Class 19: 0.2222
# * Prec @1: 0.1955
# current_learning_rate 0.0001
# Epoch: [4][0/63]	Time 0.243 (0.243)	Loss 2.6343 (2.6343)	Prec @1 0.1875 (0.1875)
# Epoch: [4][10/63]	Time 0.243 (0.243)	Loss 2.6016 (2.6103)	Prec @1 0.2266 (0.2212)
# Epoch: [4][20/63]	Time 0.242 (0.243)	Loss 2.6082 (2.6150)	Prec @1 0.2031 (0.2193)
# Epoch: [4][30/63]	Time 0.243 (0.243)	Loss 2.5512 (2.6148)	Prec @1 0.2070 (0.2228)
# Epoch: [4][40/63]	Time 0.243 (0.243)	Loss 2.6165 (2.6085)	Prec @1 0.1953 (0.2232)
# Epoch: [4][50/63]	Time 0.243 (0.243)	Loss 2.5601 (2.6063)	Prec @1 0.2109 (0.2233)
# Epoch: [4][60/63]	Time 0.243 (0.243)	Loss 2.6033 (2.6024)	Prec @1 0.2578 (0.2259)
# Epoch: [4][0/16]	Time 0.238 (0.238)
# Epoch: [4][10/16]	Time 0.238 (0.239)
# Accuracy of Class 0: 0.0176
# Accuracy of Class 1: 0.5000
# Accuracy of Class 2: 0.1990
# Accuracy of Class 3: 0.5507
# Accuracy of Class 4: 0.1776
# Accuracy of Class 5: 0.1934
# Accuracy of Class 6: 0.0421
# Accuracy of Class 7: 0.1675
# Accuracy of Class 8: 0.3654
# Accuracy of Class 9: 0.3316
# Accuracy of Class 10: 0.3763
# Accuracy of Class 11: 0.1364
# Accuracy of Class 12: 0.1497
# Accuracy of Class 13: 0.1592
# Accuracy of Class 14: 0.1374
# Accuracy of Class 15: 0.1836
# Accuracy of Class 16: 0.1200
# Accuracy of Class 17: 0.0220
# Accuracy of Class 18: 0.1244
# Accuracy of Class 19: 0.2578
# * Prec @1: 0.2107
# current_learning_rate 0.0001
# Epoch: [5][0/63]	Time 0.243 (0.243)	Loss 2.5647 (2.5647)	Prec @1 0.2188 (0.2188)
# Epoch: [5][10/63]	Time 0.243 (0.243)	Loss 2.5767 (2.5843)	Prec @1 0.2109 (0.2308)
# Epoch: [5][20/63]	Time 0.243 (0.243)	Loss 2.5410 (2.5731)	Prec @1 0.2891 (0.2338)
# Epoch: [5][30/63]	Time 0.243 (0.243)	Loss 2.5716 (2.5714)	Prec @1 0.2266 (0.2330)
# Epoch: [5][40/63]	Time 0.243 (0.243)	Loss 2.5196 (2.5727)	Prec @1 0.2227 (0.2300)
# Epoch: [5][50/63]	Time 0.243 (0.243)	Loss 2.5168 (2.5701)	Prec @1 0.2578 (0.2318)
# Epoch: [5][60/63]	Time 0.243 (0.243)	Loss 2.5445 (2.5686)	Prec @1 0.2383 (0.2317)
# Epoch: [5][0/16]	Time 0.239 (0.239)
# Epoch: [5][10/16]	Time 0.239 (0.239)
# Accuracy of Class 0: 0.0294
# Accuracy of Class 1: 0.5000
# Accuracy of Class 2: 0.2786
# Accuracy of Class 3: 0.5121
# Accuracy of Class 4: 0.2150
# Accuracy of Class 5: 0.2762
# Accuracy of Class 6: 0.0263
# Accuracy of Class 7: 0.0861
# Accuracy of Class 8: 0.3365
# Accuracy of Class 9: 0.3368
# Accuracy of Class 10: 0.2216
# Accuracy of Class 11: 0.1414
# Accuracy of Class 12: 0.1551
# Accuracy of Class 13: 0.2040
# Accuracy of Class 14: 0.1754
# Accuracy of Class 15: 0.2802
# Accuracy of Class 16: 0.1900
# Accuracy of Class 17: 0.0352
# Accuracy of Class 18: 0.0777
# Accuracy of Class 19: 0.1867
# * Prec @1: 0.2130
# current_learning_rate 0.0001
# Epoch: [6][0/63]	Time 0.243 (0.243)	Loss 2.5708 (2.5708)	Prec @1 0.2188 (0.2188)
# Epoch: [6][10/63]	Time 0.243 (0.243)	Loss 2.5062 (2.5599)	Prec @1 0.2539 (0.2422)
# Epoch: [6][20/63]	Time 0.242 (0.243)	Loss 2.5822 (2.5521)	Prec @1 0.1953 (0.2375)
# Epoch: [6][30/63]	Time 0.243 (0.243)	Loss 2.5327 (2.5588)	Prec @1 0.2070 (0.2306)
# Epoch: [6][40/63]	Time 0.243 (0.243)	Loss 2.5102 (2.5515)	Prec @1 0.2539 (0.2375)
# Epoch: [6][50/63]	Time 0.243 (0.243)	Loss 2.4757 (2.5452)	Prec @1 0.2891 (0.2403)
# Epoch: [6][60/63]	Time 0.242 (0.243)	Loss 2.6074 (2.5397)	Prec @1 0.1992 (0.2412)
# Epoch: [6][0/16]	Time 0.238 (0.238)
# Epoch: [6][10/16]	Time 0.238 (0.239)
# Accuracy of Class 0: 0.0294
# Accuracy of Class 1: 0.5054
# Accuracy of Class 2: 0.3582
# Accuracy of Class 3: 0.5217
# Accuracy of Class 4: 0.2150
# Accuracy of Class 5: 0.3591
# Accuracy of Class 6: 0.0789
# Accuracy of Class 7: 0.0813
# Accuracy of Class 8: 0.3221
# Accuracy of Class 9: 0.2798
# Accuracy of Class 10: 0.1289
# Accuracy of Class 11: 0.1869
# Accuracy of Class 12: 0.1765
# Accuracy of Class 13: 0.1493
# Accuracy of Class 14: 0.1422
# Accuracy of Class 15: 0.3430
# Accuracy of Class 16: 0.1200
# Accuracy of Class 17: 0.0352
# Accuracy of Class 18: 0.0777
# Accuracy of Class 19: 0.1733
# * Prec @1: 0.2135
# current_learning_rate 0.0001
# Epoch: [7][0/63]	Time 0.243 (0.243)	Loss 2.5290 (2.5290)	Prec @1 0.2500 (0.2500)
# Epoch: [7][10/63]	Time 0.244 (0.243)	Loss 2.5753 (2.5151)	Prec @1 0.2070 (0.2443)
# Epoch: [7][20/63]	Time 0.243 (0.243)	Loss 2.5414 (2.5171)	Prec @1 0.2070 (0.2413)
# Epoch: [7][30/63]	Time 0.243 (0.243)	Loss 2.5428 (2.5146)	Prec @1 0.2266 (0.2463)
# Epoch: [7][40/63]	Time 0.243 (0.243)	Loss 2.5151 (2.5151)	Prec @1 0.2188 (0.2450)
# Epoch: [7][50/63]	Time 0.243 (0.243)	Loss 2.4926 (2.5135)	Prec @1 0.2305 (0.2462)
# Epoch: [7][60/63]	Time 0.243 (0.243)	Loss 2.5483 (2.5157)	Prec @1 0.2070 (0.2421)
# Epoch: [7][0/16]	Time 0.240 (0.240)
# Epoch: [7][10/16]	Time 0.241 (0.239)
# Accuracy of Class 0: 0.0176
# Accuracy of Class 1: 0.4620
# Accuracy of Class 2: 0.3184
# Accuracy of Class 3: 0.5314
# Accuracy of Class 4: 0.2150
# Accuracy of Class 5: 0.3039
# Accuracy of Class 6: 0.0105
# Accuracy of Class 7: 0.0622
# Accuracy of Class 8: 0.3462
# Accuracy of Class 9: 0.3316
# Accuracy of Class 10: 0.1959
# Accuracy of Class 11: 0.1515
# Accuracy of Class 12: 0.1711
# Accuracy of Class 13: 0.2687
# Accuracy of Class 14: 0.1564
# Accuracy of Class 15: 0.2415
# Accuracy of Class 16: 0.1400
# Accuracy of Class 17: 0.0441
# Accuracy of Class 18: 0.0881
# Accuracy of Class 19: 0.2978
# * Prec @1: 0.2182
# current_learning_rate 0.0001
# Epoch: [8][0/63]	Time 0.243 (0.243)	Loss 2.5300 (2.5300)	Prec @1 0.2227 (0.2227)
# Epoch: [8][10/63]	Time 0.242 (0.243)	Loss 2.4807 (2.4911)	Prec @1 0.2695 (0.2511)
# Epoch: [8][20/63]	Time 0.243 (0.243)	Loss 2.5184 (2.5010)	Prec @1 0.2266 (0.2474)
# Epoch: [8][30/63]	Time 0.243 (0.243)	Loss 2.5424 (2.4998)	Prec @1 0.2070 (0.2494)
# Epoch: [8][40/63]	Time 0.243 (0.243)	Loss 2.4972 (2.4983)	Prec @1 0.2070 (0.2494)
# Epoch: [8][50/63]	Time 0.243 (0.243)	Loss 2.4626 (2.4940)	Prec @1 0.2500 (0.2494)
# Epoch: [8][60/63]	Time 0.243 (0.243)	Loss 2.5043 (2.4942)	Prec @1 0.1953 (0.2493)
# Epoch: [8][0/16]	Time 0.239 (0.239)
# Epoch: [8][10/16]	Time 0.239 (0.239)
# Accuracy of Class 0: 0.0529
# Accuracy of Class 1: 0.5109
# Accuracy of Class 2: 0.4129
# Accuracy of Class 3: 0.5845
# Accuracy of Class 4: 0.2430
# Accuracy of Class 5: 0.3315
# Accuracy of Class 6: 0.0684
# Accuracy of Class 7: 0.1531
# Accuracy of Class 8: 0.3606
# Accuracy of Class 9: 0.2487
# Accuracy of Class 10: 0.2165
# Accuracy of Class 11: 0.0707
# Accuracy of Class 12: 0.1390
# Accuracy of Class 13: 0.1095
# Accuracy of Class 14: 0.1327
# Accuracy of Class 15: 0.2850
# Accuracy of Class 16: 0.1050
# Accuracy of Class 17: 0.0308
# Accuracy of Class 18: 0.1658
# Accuracy of Class 19: 0.2044
# * Prec @1: 0.2210
# current_learning_rate 0.0001
# Epoch: [9][0/63]	Time 0.243 (0.243)	Loss 2.4656 (2.4656)	Prec @1 0.2500 (0.2500)
# Epoch: [9][10/63]	Time 0.242 (0.243)	Loss 2.4508 (2.4978)	Prec @1 0.2656 (0.2376)
# Epoch: [9][20/63]	Time 0.243 (0.243)	Loss 2.4633 (2.4871)	Prec @1 0.2734 (0.2520)
# Epoch: [9][30/63]	Time 0.243 (0.243)	Loss 2.4937 (2.4795)	Prec @1 0.2539 (0.2544)
# Epoch: [9][40/63]	Time 0.243 (0.243)	Loss 2.4902 (2.4768)	Prec @1 0.2891 (0.2546)
# Epoch: [9][50/63]	Time 0.243 (0.243)	Loss 2.5282 (2.4767)	Prec @1 0.2305 (0.2542)
# Epoch: [9][60/63]	Time 0.243 (0.243)	Loss 2.5345 (2.4783)	Prec @1 0.2148 (0.2531)
# Epoch: [9][0/16]	Time 0.243 (0.243)
# Epoch: [9][10/16]	Time 0.239 (0.239)
# Accuracy of Class 0: 0.0118
# Accuracy of Class 1: 0.4565
# Accuracy of Class 2: 0.3483
# Accuracy of Class 3: 0.5314
# Accuracy of Class 4: 0.2336
# Accuracy of Class 5: 0.3094
# Accuracy of Class 6: 0.0421
# Accuracy of Class 7: 0.0622
# Accuracy of Class 8: 0.3462
# Accuracy of Class 9: 0.3420
# Accuracy of Class 10: 0.1856
# Accuracy of Class 11: 0.1919
# Accuracy of Class 12: 0.1551
# Accuracy of Class 13: 0.2289
# Accuracy of Class 14: 0.1659
# Accuracy of Class 15: 0.2512
# Accuracy of Class 16: 0.1250
# Accuracy of Class 17: 0.0396
# Accuracy of Class 18: 0.1399
# Accuracy of Class 19: 0.2667
# * Prec @1: 0.2220
# current_learning_rate 0.0001
# Epoch: [10][0/63]	Time 0.243 (0.243)	Loss 2.4571 (2.4571)	Prec @1 0.2891 (0.2891)
# Epoch: [10][10/63]	Time 0.243 (0.243)	Loss 2.4070 (2.4596)	Prec @1 0.2930 (0.2571)
# Epoch: [10][20/63]	Time 0.243 (0.243)	Loss 2.4179 (2.4599)	Prec @1 0.2773 (0.2569)
# Epoch: [10][30/63]	Time 0.244 (0.243)	Loss 2.4794 (2.4658)	Prec @1 0.2773 (0.2553)
# Epoch: [10][40/63]	Time 0.243 (0.243)	Loss 2.4701 (2.4654)	Prec @1 0.2617 (0.2558)
# Epoch: [10][50/63]	Time 0.243 (0.243)	Loss 2.4769 (2.4628)	Prec @1 0.2148 (0.2568)
# Epoch: [10][60/63]	Time 0.242 (0.243)	Loss 2.3837 (2.4650)	Prec @1 0.3086 (0.2564)
# Epoch: [10][0/16]	Time 0.240 (0.240)
# Epoch: [10][10/16]	Time 0.239 (0.239)
# Accuracy of Class 0: 0.1000
# Accuracy of Class 1: 0.5326
# Accuracy of Class 2: 0.2935
# Accuracy of Class 3: 0.4976
# Accuracy of Class 4: 0.2336
# Accuracy of Class 5: 0.2210
# Accuracy of Class 6: 0.0105
# Accuracy of Class 7: 0.1005
# Accuracy of Class 8: 0.4327
# Accuracy of Class 9: 0.3368
# Accuracy of Class 10: 0.2784
# Accuracy of Class 11: 0.1111
# Accuracy of Class 12: 0.1497
# Accuracy of Class 13: 0.2786
# Accuracy of Class 14: 0.1137
# Accuracy of Class 15: 0.3140
# Accuracy of Class 16: 0.1250
# Accuracy of Class 17: 0.0220
# Accuracy of Class 18: 0.1295
# Accuracy of Class 19: 0.1956
# * Prec @1: 0.2233
# current_learning_rate 0.0001
# Epoch: [11][0/63]	Time 0.243 (0.243)	Loss 2.4320 (2.4320)	Prec @1 0.2539 (0.2539)
# Epoch: [11][10/63]	Time 0.243 (0.243)	Loss 2.4731 (2.4755)	Prec @1 0.2344 (0.2464)
# Epoch: [11][20/63]	Time 0.244 (0.243)	Loss 2.5035 (2.4525)	Prec @1 0.2266 (0.2556)
# Epoch: [11][30/63]	Time 0.243 (0.243)	Loss 2.4485 (2.4449)	Prec @1 0.2891 (0.2616)
# Epoch: [11][40/63]	Time 0.243 (0.243)	Loss 2.4405 (2.4507)	Prec @1 0.2773 (0.2591)
# Epoch: [11][50/63]	Time 0.243 (0.243)	Loss 2.3807 (2.4520)	Prec @1 0.2539 (0.2580)
# Epoch: [11][60/63]	Time 0.243 (0.243)	Loss 2.3982 (2.4526)	Prec @1 0.2930 (0.2598)
# Epoch: [11][0/16]	Time 0.240 (0.240)
# Epoch: [11][10/16]	Time 0.239 (0.239)
# Accuracy of Class 0: 0.0353
# Accuracy of Class 1: 0.4946
# Accuracy of Class 2: 0.3035
# Accuracy of Class 3: 0.6087
# Accuracy of Class 4: 0.1495
# Accuracy of Class 5: 0.3260
# Accuracy of Class 6: 0.0947
# Accuracy of Class 7: 0.0909
# Accuracy of Class 8: 0.3606
# Accuracy of Class 9: 0.2953
# Accuracy of Class 10: 0.3041
# Accuracy of Class 11: 0.1515
# Accuracy of Class 12: 0.1818
# Accuracy of Class 13: 0.1891
# Accuracy of Class 14: 0.1327
# Accuracy of Class 15: 0.1932
# Accuracy of Class 16: 0.1800
# Accuracy of Class 17: 0.0573
# Accuracy of Class 18: 0.1347
# Accuracy of Class 19: 0.2178
# * Prec @1: 0.2243
# current_learning_rate 0.0001
# Epoch: [12][0/63]	Time 0.243 (0.243)	Loss 2.3492 (2.3492)	Prec @1 0.2891 (0.2891)
# Epoch: [12][10/63]	Time 0.243 (0.243)	Loss 2.5517 (2.4396)	Prec @1 0.2070 (0.2578)
# Epoch: [12][20/63]	Time 0.243 (0.243)	Loss 2.3815 (2.4308)	Prec @1 0.3047 (0.2651)
# Epoch: [12][30/63]	Time 0.242 (0.243)	Loss 2.4107 (2.4298)	Prec @1 0.2852 (0.2685)
# Epoch: [12][40/63]	Time 0.243 (0.243)	Loss 2.4050 (2.4394)	Prec @1 0.2422 (0.2647)
# Epoch: [12][50/63]	Time 0.243 (0.243)	Loss 2.3857 (2.4378)	Prec @1 0.2539 (0.2640)
# Epoch: [12][60/63]	Time 0.243 (0.243)	Loss 2.5029 (2.4390)	Prec @1 0.2227 (0.2633)
# Epoch: [12][0/16]	Time 0.239 (0.239)
# Epoch: [12][10/16]	Time 0.239 (0.240)
# Accuracy of Class 0: 0.0588
# Accuracy of Class 1: 0.5761
# Accuracy of Class 2: 0.3980
# Accuracy of Class 3: 0.5556
# Accuracy of Class 4: 0.1963
# Accuracy of Class 5: 0.2818
# Accuracy of Class 6: 0.0947
# Accuracy of Class 7: 0.1100
# Accuracy of Class 8: 0.4327
# Accuracy of Class 9: 0.3057
# Accuracy of Class 10: 0.2216
# Accuracy of Class 11: 0.1263
# Accuracy of Class 12: 0.1925
# Accuracy of Class 13: 0.1095
# Accuracy of Class 14: 0.1422
# Accuracy of Class 15: 0.2077
# Accuracy of Class 16: 0.1200
# Accuracy of Class 17: 0.0396
# Accuracy of Class 18: 0.1088
# Accuracy of Class 19: 0.1956
# * Prec @1: 0.2228
# current_learning_rate 0.0001
# Epoch: [13][0/63]	Time 0.244 (0.244)	Loss 2.4105 (2.4105)	Prec @1 0.2539 (0.2539)
# Epoch: [13][10/63]	Time 0.243 (0.243)	Loss 2.4535 (2.4217)	Prec @1 0.2812 (0.2674)
# Epoch: [13][20/63]	Time 0.244 (0.243)	Loss 2.4234 (2.4236)	Prec @1 0.2539 (0.2721)
# Epoch: [13][30/63]	Time 0.243 (0.243)	Loss 2.3918 (2.4212)	Prec @1 0.2812 (0.2693)
# Epoch: [13][40/63]	Time 0.243 (0.243)	Loss 2.4617 (2.4291)	Prec @1 0.2578 (0.2687)
# Epoch: [13][50/63]	Time 0.243 (0.243)	Loss 2.3731 (2.4246)	Prec @1 0.3047 (0.2726)
# Epoch: [13][60/63]	Time 0.243 (0.243)	Loss 2.4404 (2.4274)	Prec @1 0.2617 (0.2706)
# Epoch: [13][0/16]	Time 0.240 (0.240)
# Epoch: [13][10/16]	Time 0.239 (0.240)
# Accuracy of Class 0: 0.0118
# Accuracy of Class 1: 0.5163
# Accuracy of Class 2: 0.2935
# Accuracy of Class 3: 0.5507
# Accuracy of Class 4: 0.2103
# Accuracy of Class 5: 0.3370
# Accuracy of Class 6: 0.0211
# Accuracy of Class 7: 0.0909
# Accuracy of Class 8: 0.4279
# Accuracy of Class 9: 0.3057
# Accuracy of Class 10: 0.2680
# Accuracy of Class 11: 0.1515
# Accuracy of Class 12: 0.2193
# Accuracy of Class 13: 0.2587
# Accuracy of Class 14: 0.1564
# Accuracy of Class 15: 0.2609
# Accuracy of Class 16: 0.1150
# Accuracy of Class 17: 0.0220
# Accuracy of Class 18: 0.1036
# Accuracy of Class 19: 0.1956
# * Prec @1: 0.2253
# current_learning_rate 0.0001
# Epoch: [14][0/63]	Time 0.243 (0.243)	Loss 2.3645 (2.3645)	Prec @1 0.3164 (0.3164)
# Epoch: [14][10/63]	Time 0.243 (0.243)	Loss 2.4244 (2.4101)	Prec @1 0.2773 (0.2781)
# Epoch: [14][20/63]	Time 0.243 (0.243)	Loss 2.4202 (2.4259)	Prec @1 0.2578 (0.2686)
# Epoch: [14][30/63]	Time 0.243 (0.243)	Loss 2.3919 (2.4163)	Prec @1 0.2461 (0.2705)
# Epoch: [14][40/63]	Time 0.243 (0.243)	Loss 2.3240 (2.4140)	Prec @1 0.2891 (0.2741)
# Epoch: [14][50/63]	Time 0.243 (0.243)	Loss 2.3866 (2.4155)	Prec @1 0.2812 (0.2704)
# Epoch: [14][60/63]	Time 0.243 (0.243)	Loss 2.4720 (2.4170)	Prec @1 0.2656 (0.2703)
# Epoch: [14][0/16]	Time 0.238 (0.238)
# Epoch: [14][10/16]	Time 0.239 (0.240)
# Accuracy of Class 0: 0.0294
# Accuracy of Class 1: 0.5435
# Accuracy of Class 2: 0.2537
# Accuracy of Class 3: 0.5314
# Accuracy of Class 4: 0.2103
# Accuracy of Class 5: 0.3094
# Accuracy of Class 6: 0.0368
# Accuracy of Class 7: 0.1435
# Accuracy of Class 8: 0.3846
# Accuracy of Class 9: 0.3472
# Accuracy of Class 10: 0.3196
# Accuracy of Class 11: 0.1515
# Accuracy of Class 12: 0.2567
# Accuracy of Class 13: 0.1343
# Accuracy of Class 14: 0.1422
# Accuracy of Class 15: 0.2271
# Accuracy of Class 16: 0.1350
# Accuracy of Class 17: 0.0441
# Accuracy of Class 18: 0.1451
# Accuracy of Class 19: 0.1956
# * Prec @1: 0.2260
# current_learning_rate 0.0001
# Best Prec @1 Acccuracy: 0.2260
# Accuracy of Class 0: 0.0294
# Accuracy of Class 1: 0.5435
# Accuracy of Class 2: 0.2537
# Accuracy of Class 3: 0.5314
# Accuracy of Class 4: 0.2103
# Accuracy of Class 5: 0.3094
# Accuracy of Class 6: 0.0368
# Accuracy of Class 7: 0.1435
# Accuracy of Class 8: 0.3846
# Accuracy of Class 9: 0.3472
# Accuracy of Class 10: 0.3196
# Accuracy of Class 11: 0.1515
# Accuracy of Class 12: 0.2567
# Accuracy of Class 13: 0.1343
# Accuracy of Class 14: 0.1422
# Accuracy of Class 15: 0.2271
# Accuracy of Class 16: 0.1350
# Accuracy of Class 17: 0.0441
# Accuracy of Class 18: 0.1451
# Accuracy of Class 19: 0.1956
# Directory /content/drive/.shortcut-targets-by-id/18DzphWfHEkGdHaXfkSrWGl0v37qf7tZ-/FinalProject/checkpoints/resnet152 already exists

# %%
import torch

def compute_metrics_from_confusion_matrix(cm):
    """
    cm: torch.Tensor of shape (num_classes, num_classes)
    returns: dict with precision, recall, f1 per class
    """
    num_classes = cm.shape[0]
    metrics = {}

    eps = 1e-8  # small epsilon to avoid divide by zero

    TP = cm.diag()
    FP = cm.sum(0) - TP
    FN = cm.sum(1) - TP
    TN = cm.sum() - (TP + FP + FN)

    precision = TP / (TP + FP + eps)
    recall = TP / (TP + FN + eps)
    f1 = 2 * precision * recall / (precision + recall + eps)

    metrics['precision_per_class'] = precision
    metrics['recall_per_class'] = recall
    metrics['f1_per_class'] = f1
    metrics['accuracy_per_class'] = TP / (TP + FN + eps)

    # Also compute macro-averaged scores
    metrics['macro_precision'] = precision.mean()
    metrics['macro_recall'] = recall.mean()
    metrics['macro_f1'] = f1.mean()
    metrics['overall_accuracy'] = TP.sum() / cm.sum()

    return metrics

# %%
cm, acc, loss = Trainer.evaluate_step(trainer,1)

compute_metrics_from_confusion_matrix(cm)
cm
# Out:
# Epoch: [1][0/16]	Time 0.259 (0.259)
# Epoch: [1][10/16]	Time 0.239 (0.241)
# Accuracy of Class 0: 0.0294
# Accuracy of Class 1: 0.5435
# Accuracy of Class 2: 0.2537
# Accuracy of Class 3: 0.5314
# Accuracy of Class 4: 0.2103
# Accuracy of Class 5: 0.3094
# Accuracy of Class 6: 0.0368
# Accuracy of Class 7: 0.1435
# Accuracy of Class 8: 0.3846
# Accuracy of Class 9: 0.3472
# Accuracy of Class 10: 0.3196
# Accuracy of Class 11: 0.1515
# Accuracy of Class 12: 0.2567
# Accuracy of Class 13: 0.1343
# Accuracy of Class 14: 0.1422
# Accuracy of Class 15: 0.2271
# Accuracy of Class 16: 0.1350
# Accuracy of Class 17: 0.0441
# Accuracy of Class 18: 0.1451
# Accuracy of Class 19: 0.1956
# * Prec @1: 0.2260
# tensor([[0.0294, 0.0707, 0.0697, 0.0242, 0.0327, 0.0166, 0.0211, 0.0574, 0.0000,
#          0.0518, 0.0515, 0.0909, 0.0963, 0.0448, 0.0332, 0.0290, 0.0450, 0.0441,
#          0.0466, 0.0044],
#         [0.0176, 0.5435, 0.0299, 0.0097, 0.0140, 0.0497, 0.0105, 0.0239, 0.0096,
#          0.0207, 0.0464, 0.0556, 0.0374, 0.0149, 0.0332, 0.0097, 0.0250, 0.0000,
#          0.0207, 0.0000],
#         [0.0765, 0.1033, 0.2537, 0.0145, 0.0140, 0.0110, 0.0000, 0.0861, 0.0096,
#          0.0311, 0.0515, 0.0556, 0.0535, 0.0896, 0.0427, 0.0145, 0.0300, 0.0132,
#          0.0622, 0.0089],
#         [0.0000, 0.0109, 0.0100, 0.5314, 0.1168, 0.0442, 0.0000, 0.0144, 0.0096,
#          0.1399, 0.0052, 0.0101, 0.0267, 0.0000, 0.0284, 0.0338, 0.0250, 0.0044,
#          0.0052, 0.0000],
#         [0.0176, 0.0272, 0.0050, 0.3043, 0.2103, 0.0497, 0.0000, 0.0335, 0.0192,
#          0.0829, 0.0206, 0.0051, 0.0802, 0.0050, 0.0474, 0.0386, 0.0200, 0.0352,
#          0.0311, 0.0178],
#         [0.0059, 0.0217, 0.0050, 0.0242, 0.0047, 0.3094, 0.0158, 0.0239, 0.1154,
#          0.0881, 0.0515, 0.0152, 0.0374, 0.0149, 0.0142, 0.0338, 0.0200, 0.0088,
#          0.0104, 0.1022],
#         [0.0059, 0.0435, 0.0199, 0.0290, 0.0327, 0.0939, 0.0368, 0.0335, 0.0433,
#          0.0725, 0.1031, 0.0253, 0.0909, 0.0498, 0.0190, 0.0628, 0.0350, 0.0220,
#          0.0466, 0.0889],
#         [0.0353, 0.1196, 0.0945, 0.0193, 0.0561, 0.0166, 0.0368, 0.1435, 0.0240,
#          0.0207, 0.0670, 0.0606, 0.1070, 0.0597, 0.0569, 0.0386, 0.0450, 0.0088,
#          0.0311, 0.0133],
#         [0.0118, 0.0217, 0.0050, 0.0338, 0.0467, 0.0994, 0.0316, 0.0048, 0.3846,
#          0.0311, 0.0619, 0.0152, 0.0856, 0.0149, 0.0237, 0.0386, 0.0000, 0.0088,
#          0.0207, 0.0889],
#         [0.0176, 0.0163, 0.0149, 0.1449, 0.0748, 0.0773, 0.0105, 0.0048, 0.0096,
#          0.3472, 0.0361, 0.0152, 0.0321, 0.0100, 0.0332, 0.0386, 0.0250, 0.0176,
#          0.0311, 0.0178],
#         [0.0294, 0.0435, 0.0149, 0.0242, 0.0140, 0.0387, 0.0105, 0.0144, 0.0288,
#          0.0777, 0.3196, 0.0404, 0.0535, 0.0796, 0.0284, 0.0338, 0.0450, 0.0220,
#          0.0466, 0.0222],
#         [0.0412, 0.1087, 0.0547, 0.0145, 0.0093, 0.0829, 0.0526, 0.0431, 0.0096,
#          0.0363, 0.0670, 0.1515, 0.0535, 0.0697, 0.0427, 0.0290, 0.0350, 0.0485,
#          0.0622, 0.0000],
#         [0.0294, 0.0380, 0.0149, 0.0483, 0.0421, 0.0497, 0.0316, 0.0335, 0.0240,
#          0.0259, 0.0361, 0.0253, 0.2567, 0.0697, 0.0521, 0.0725, 0.0250, 0.0132,
#          0.0311, 0.0311],
#         [0.0235, 0.0870, 0.0697, 0.0242, 0.0327, 0.0663, 0.0684, 0.0383, 0.0240,
#          0.0466, 0.0515, 0.0505, 0.0481, 0.1343, 0.0379, 0.0386, 0.0200, 0.0264,
#          0.0984, 0.0311],
#         [0.0294, 0.0435, 0.0498, 0.0628, 0.0374, 0.0718, 0.0368, 0.0335, 0.0337,
#          0.0829, 0.0825, 0.0253, 0.1123, 0.0149, 0.1422, 0.0193, 0.0650, 0.0352,
#          0.0415, 0.0400],
#         [0.0294, 0.0272, 0.0149, 0.0145, 0.0327, 0.0552, 0.0105, 0.0239, 0.0192,
#          0.1036, 0.0773, 0.0455, 0.1176, 0.0199, 0.0474, 0.2271, 0.0850, 0.0264,
#          0.0259, 0.0356],
#         [0.0353, 0.0707, 0.0348, 0.0290, 0.0280, 0.0663, 0.0211, 0.0239, 0.0433,
#          0.0570, 0.0670, 0.0455, 0.0695, 0.0100, 0.0427, 0.0918, 0.1350, 0.0088,
#          0.0777, 0.0533],
#         [0.0176, 0.0380, 0.0547, 0.0725, 0.0374, 0.0939, 0.0421, 0.0813, 0.0288,
#          0.1192, 0.0722, 0.0202, 0.1230, 0.0647, 0.0806, 0.0386, 0.0400, 0.0441,
#          0.0674, 0.0089],
#         [0.0294, 0.1141, 0.0348, 0.0242, 0.0140, 0.0276, 0.0211, 0.0526, 0.0192,
#          0.0622, 0.1031, 0.0657, 0.0214, 0.0697, 0.0427, 0.0338, 0.0700, 0.0220,
#          0.1451, 0.0089],
#         [0.0059, 0.0272, 0.0100, 0.0193, 0.0467, 0.2210, 0.0368, 0.0048, 0.2308,
#          0.0363, 0.0515, 0.0101, 0.0695, 0.0249, 0.0474, 0.0145, 0.0400, 0.0132,
#          0.0104, 0.1956]])

# %%
import sklearn
fig, ax = plt.subplots(figsize=(12, 12))
x = sklearn.metrics.ConfusionMatrixDisplay(cm, display_labels=label_names.values())
x.plot(ax=ax, values_format='.2f')
plt.xticks(rotation=75)
plt.title("Confusion Matrix for " + cfg['model_name'])
plt.show()
